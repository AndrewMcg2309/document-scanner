# %%
# Transformation Assignment

# %%
from PIL import Image
import cv2
import numpy as np
from matplotlib import pyplot as plt 
from matplotlib import image as image
import easygui

image = cv2.imread("Faded.jpg")
cv2.imwrite('Faded.jpg', image)
plt.imshow(image)
plt.show()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Color in range of 0-255 in grayscale image
# Greyscale range is binary so it only has one value per pixel
rangeG = cv2.inRange(gray, 50, 100)

# Using "INPAINT_TELEA" for joining lines with same intensity
# rangeG from our grayscale color range
image = cv2.inpaint(image, rangeG, 5, cv2.INPAINT_TELEA)

plt.imshow(image)
plt.show()

# %%
#px = image[50, 440]
#print(px)

#px2 = image[50, 500]
#print(px2)

#[86 88 83]
#[54 56 53]

#new = image.crop[4:330, 56:462] = (66, 44, 55)

img = image.crop((4,56, 462,330))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-69f9309f80c4> in <module>
#      10 #new = image.crop[4:330, 56:462] = (66, 44, 55)
#      11
# ---> 12 img = image.crop((4,56, 462,330))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'crop'
